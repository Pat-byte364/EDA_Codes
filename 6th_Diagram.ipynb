# %%
import piplite
await piplite.install("seaborn")

# %%
import piplite
await piplite.install("squarify")

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import squarify

# %%
df = pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
plt.figure()
sns.histplot(df["SepalLengthCm"], kde= True)
plt.title("Histogram: Distribution")
plt.show()

# %%
plt.figure()
sns.boxplot(x=df["SepalLengthCm"])
plt.title("Boxplot: Outliers")
plt.show()

# %%
for col in df.select_dtypes(include='number').columns:
    plt.figure(figsize=(10,4))
    
    plt.subplot(1,2,1)
    sns.histplot(df[col], kde=True)
    plt.title(f'Histogram of {col}')
    
    plt.subplot(1,2,2)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    
    plt.show()

# %%
plt.figure(figsize=(6,6))
squarify.plot(
    sizes=species_counts.values,
    label=species_counts.index
    
)
plt.title("Species Distribution")
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.kdeplot(data=df, x='SepalLengthCm', hue='Species', fill=True)
plt.title("Density Plot - SepalLengthCm")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(df['SepalLengthCm'])
plt.title("Line Plot - SepalLengthCm")
plt.xlabel("Index")
plt.ylabel("SepalLengthCm")
plt.show()

# %%
Q1 = df['SepalLengthCm'].quantile(0.25)
Q3 = df['SepalLengthCm'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers_sepal_length = df[(df['SepalLengthCm'] < lower) | (df['SepalLengthCm'] > upper)]

print("SepalLengthCm outliers:", len(outliers_sepal_length))
# Out:
# SepalLengthCm outliers: 0
