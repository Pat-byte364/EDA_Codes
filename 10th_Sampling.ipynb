# %%
import numpy as np
import matplotlib.pyplot as plt

population = np.random.normal(loc=50, scale=10, size=10000)

# %%
plt.figure()
plt.hist(population, bins=50)
plt.title("Population Distribution")
plt.show()

# %%
sample = np.random.choice(population, size=30)

print("Sample Mean:", np.mean(sample))
# Out:
# Sample Mean: 52.967963813420695

# %%
sample_means = []

for i in range(100):
    sample = np.random.choice(population, size=30)
    sample_means.append(np.mean(sample))

# %%
plt.hist(sample_means, bins=30)
plt.title("Sampling Distribution of Mean")
plt.show()

# %%
print("Population Mean:", np.mean(population))
print("Mean of Sample Means:", np.mean(sample_means))

print("Population SD:", np.std(population))
print("SD of Sample Means:", np.std(sample_means))
# Out:
# Population Mean: 49.97003924188848
# Mean of Sample Means: 50.11349481689095
# Population SD: 10.002260734602
# SD of Sample Means: 1.9196354717360304
